# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt

import datasets_util
import vis_util
import lpca
from lego import lego, util

VIS = vis_util.Visualize('figures/_truncated_torus/')
# Out:
# matplotlib.get_backend() =  inline

# %%
X0_, labels0_, normal_dir_ = datasets_util.curvedtorus3d_with_normal_dir(n=10000)

# %%
# truncate the torus
x_max = 0.14
mask = (X0_[:,0] < x_max) & (X0_[:,2] < 0)
X0 = X0_[mask,:]
labels0 = labels0_[mask,:]
normal_dir = normal_dir_[mask,:]

# %%
theta = labels0[:,0]

# %%
np.random.seed(42)
noise_r = 0.01 + 0.05*(1+np.cos(2*theta))/2
noise = np.random.uniform(-1, 1, X0.shape[0])
noise = noise_r*noise
X = X0 + noise[:,None]*normal_dir

# %%
labels = labels0

# %%
VIS.data(X0, noise_r, elev=26, azim=-42, cmap='viridis', colorbar=True, title='', save_fn='clean_data', figsize=(5,5), show_axis=False)

# %%
VIS.data(X, noise_r, elev=26, azim=-42, cmap='viridis', colorbar=True, title='', save_fn='noisy_data', figsize=(5,5), show_axis=False)

# %%
# a subsample of points to visualize tangent spaces
n_subsample = 200
np.random.seed(42)
subsample_inds = np.random.choice(np.arange(X.shape[0]), n_subsample, replace=False)

# %%
emb_dim = 2
k_nn = 14

# %% [markdown]
# # LPCA on noiseless data

# %%
gt_estimate = lpca.lpca(X0, opts = {'emb_dim': emb_dim, 'k_nn': k_nn})
# Out:
# [LPCA] Nearest neighbors: 0.0260 s
# [LPCA] Tangent basis estimation: 0.9089 s
# [LPCA] Total execution time: 0.9349 s

# %%
gt_estimate['tang_basis'].shape
# Out:
# (3490, 2, 3)

# %%
VIS.plot_tangent_vectors_2d_in_3d(
    gt_estimate['tang_basis'],
    X0, X0, subsample_inds,
    title='', save_fn='gt_tang_basis'
)

# %% [markdown]
# # LPCA on noisy data

# %%
lpca_estimate = lpca.lpca(X, opts = {'emb_dim': emb_dim, 'k_nn': k_nn})
# Out:
# [LPCA] Nearest neighbors: 0.0248 s
# [LPCA] Tangent basis estimation: 0.8996 s
# [LPCA] Total execution time: 0.9246 s

# %%
VIS.plot_tangent_vectors_2d_in_3d(
    lpca_estimate['tang_basis'],
    X0, X0, subsample_inds,
    title='', save_fn='lpca_tang_basis'
)

# %% [markdown]
# # LEGO on noisy data

# %%
n_eig_for_grad = 20
n_eig = 100
lego_estimate = lego.lego(
    X,
    opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad}, 
    gl_opts={'n_eig': n_eig}
)
# Out:
# [LEGO] Nearest neighbors & diameter: 0.0263 s
# [LEGO] Graph Laplacian spectrum: 0.2114 s
# [LEGO] Gradient first-order approx: 0.0922 s
# [LEGO] Gradient regularization: 0.0112 s
# [LEGO] Tangent basis estimation: 0.9009 s
# [LEGO] Total execution time: 1.2421 s

# %%
VIS.plot_tangent_vectors_2d_in_3d(
    lego_estimate['tang_basis'],
    X0, X0, subsample_inds,
    title='', save_fn='lego_tang_basis'
)

# %% [markdown]
# # Error of LPCA and LEGO estimates

# %%
color = {'lpca': 'red', 'lego': 'green'}
error = {
    'lpca': {'lpca': util.tang_basis_estimate_error(lpca_estimate['tang_basis'], gt_estimate['tang_basis'])},
    'lego': {'lego': util.tang_basis_estimate_error(lego_estimate['tang_basis'], gt_estimate['tang_basis'])},
}

# %%
_ = VIS.global_distortion_viloinplot_overlay(
    error, log_scale=False, legend=False, filled=False,
    color = color, remove_annotation=True, offset2=0, offset1=0,
    title='', label='', figsize=(2,3), save_fn='error_violins'
)

# %%
VIS.compare_principal_angle_discrep(
    X0, [error['lpca']['lpca'], error['lego']['lego']],
    vmin=0, vmax=1, cmap='hot', save_fn='lpca_vs_lego_tang_estimate_errors'
)

# %% [markdown]
# # Local intrinsic dimension estimation
#
# We simply change the embedding dimension to be equal to the ambient dimension plot the variance explained in each dimension

# %%
ambient_dim = X.shape[1]

# %%
lpca_estimate_for_lid = lpca.lpca(X, opts = {'emb_dim': ambient_dim, 'k_nn': k_nn})
# Out:
# [LPCA] Nearest neighbors: 0.0258 s
# [LPCA] Tangent basis estimation: 0.0769 s
# [LPCA] Total execution time: 0.1028 s

# %%
VIS.plot_var_exp_violin_plot(
    lpca_estimate_for_lid['var_explained'], color='r', save_fn='lpca_lid_estimate'
)

# %%
lego_estimate_for_lid = lego.lego(
    X,
    opts={'emb_dim': ambient_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad}, 
    gl_opts={'n_eig': n_eig}
)
# Out:
# [LEGO] Nearest neighbors & diameter: 0.0256 s
# [LEGO] Graph Laplacian spectrum: 0.2079 s
# [LEGO] Gradient first-order approx: 0.0821 s
# [LEGO] Gradient regularization: 0.0096 s
# [LEGO] Tangent basis estimation: 0.0794 s
# [LEGO] Total execution time: 0.4048 s

# %%
VIS.plot_var_exp_violin_plot(
    lego_estimate_for_lid['var_explained'], color='b', save_fn='lego_lid_estimate'
)

# %% [markdown]
# # Boundary detection
#
# Note that opts['k_nn'] and opts['k_tune'] set here are specific to boundary detection and has nothing to do with tangent space estimation.
#
# For more details please refer to https://arxiv.org/abs/2411.18942
#
# The source `bx_util.py` is derived from https://github.com/chiggum/robust_boundary_estimation/tree/19f90ff6676e4fe99c417b324431a5e04f15890e

# %%
import sys
import paths_private_
sys.path.insert(0, paths_private_.codebase_path + '/robust_boundary_estimation/src/')
import bx_util

# %%
opts = bx_util.default_opts.copy()
opts['k_nn'] = 128
opts['k_tune'] = 32
opts['local_subspace'] = gt_estimate['tang_basis'].transpose(0, 2, 1) # emb_dim is the last dimension
opts['d'] = 2
gt_bx = bx_util.estimate_bx(X, opts=opts)[0]
# Out:
# 0.004470829536706742
# 0.0010639346637608543
# 0.0005884943310208388
# 0.0004175210094458675
# 0.0003317540057977563
# 0.00025078791252339017
# 0.00017631239594742386
# 0.00013733653199706213
# 0.00011383096870156238
# 0.00010013152627195576
# 9.083028164747648e-05
# 8.557257410252848e-05
# 8.745600062787289e-05
# 7.985658685825595e-05
# 7.769969602720068e-05
# 5.652452501846735e-05
# 5.387011460924142e-05
# 3.87651799303299e-05
# 2.97145396324092e-05
# 2.3633012137460534e-05
# 2.1541771161505925e-05
# 2.0392166969891584e-05
# 1.4508996552700369e-05
# 1.235846042887813e-05
# 1.1430411332169876e-05
# 9.67332230024111e-06
# 7.013989217437591e-06
# 5.90008578619251e-06
# 5.045361488979706e-06
# 5.3591803059513225e-06
# h_per_point min max median 0.03520497628805422 0.03868598004653561 0.03619072841560587
# Sinkhorn converged at iter: 21

# %%
opts = bx_util.default_opts.copy()
opts['k_nn'] = 128
opts['k_tune'] = 32
opts['local_subspace'] = lpca_estimate['tang_basis'].transpose(0, 2, 1) # emb_dim is the last dimension
opts['d'] = 2
lpca_bx = bx_util.estimate_bx(X, opts=opts)[0]
# Out:
# 0.004470829536706742
# 0.0010639346637608543
# 0.0005884943310208388
# 0.0004175210094458675
# 0.0003317540057977563
# 0.00025078791252339017
# 0.00017631239594742386
# 0.00013733653199706213
# 0.00011383096870156238
# 0.00010013152627195576
# 9.083028164747648e-05
# 8.557257410252848e-05
# 8.745600062787289e-05
# 7.985658685825595e-05
# 7.769969602720068e-05
# 5.652452501846735e-05
# 5.387011460924142e-05
# 3.87651799303299e-05
# 2.97145396324092e-05
# 2.3633012137460534e-05
# 2.1541771161505925e-05
# 2.0392166969891584e-05
# 1.4508996552700369e-05
# 1.235846042887813e-05
# 1.1430411332169876e-05
# 9.67332230024111e-06
# 7.013989217437591e-06
# 5.90008578619251e-06
# 5.045361488979706e-06
# 5.3591803059513225e-06
# h_per_point min max median 0.03520497628805422 0.03868598004653561 0.03619072841560587
# Sinkhorn converged at iter: 21

# %%
opts = bx_util.default_opts.copy()
opts['k_nn'] = 128
opts['k_tune'] = 32
opts['local_subspace'] = lego_estimate['tang_basis'].transpose(0, 2, 1) # emb_dim is the last dimension
opts['d'] = 2
lego_bx = bx_util.estimate_bx(X, opts=opts)[0]
# Out:
# 0.004470829536706742
# 0.0010639346637608543
# 0.0005884943310208388
# 0.0004175210094458675
# 0.0003317540057977563
# 0.00025078791252339017
# 0.00017631239594742386
# 0.00013733653199706213
# 0.00011383096870156238
# 0.00010013152627195576
# 9.083028164747648e-05
# 8.557257410252848e-05
# 8.745600062787289e-05
# 7.985658685825595e-05
# 7.769969602720068e-05
# 5.652452501846735e-05
# 5.387011460924142e-05
# 3.87651799303299e-05
# 2.97145396324092e-05
# 2.3633012137460534e-05
# 2.1541771161505925e-05
# 2.0392166969891584e-05
# 1.4508996552700369e-05
# 1.235846042887813e-05
# 1.1430411332169876e-05
# 9.67332230024111e-06
# 7.013989217437591e-06
# 5.90008578619251e-06
# 5.045361488979706e-06
# 5.3591803059513225e-06
# h_per_point min max median 0.03520497628805422 0.03868598004653561 0.03619072841560587
# Sinkhorn converged at iter: 21

# %%
vis_util.plot_detected_boundary(
    X0[:,:2],
    [gt_bx, lpca_bx, lego_bx],
    ['Ground truth', 'LPCA', 'LEGO'],
    max_prctile = 14, figsize=(5,5), s=5,
    save_fpath=VIS.save_dir+'/boundaries.png'
)

# %% [markdown]
# # Manifold Learning
#
# The source is derived from feature/global-opts branch of https://github.com/Mishne-Lab/pyRATS commit: 8ad44b32a82cd6e52ad6ec17bd8b5917ec037582
#
# Several options are turned off as these may improve the distortion of the low-dimensional local views obtained via projection on the estimated tangent spaces.
#
# - `to_postprocess = False` prevents any postprocessing on local views computed from the tangent space estimates.
# - `eta_min = 1` prevents formation of intermediate views (as they may improve upon local views).
#
# Note that `eta_min = 1` significantly increases the time complexity of the algorithm, however, our main goal here is to evaluate the effect of tangent space estimates on the derived embedding without interference from the remaining components of the algorithm.
#
# We also turned off `to_tear = False` to prevent intentional tearing of the manifold.
#
# For more details please refer to https://www.biorxiv.org/content/10.1101/2024.10.31.621292v2

# %%
import sys
import paths_private_
sys.path.insert(0, paths_private_.codebase_path + '/pyRATS/src/')
from pyRATS import rats

def generate_embedding(point_cloud, model, tang_basis):
    model._fit_nbrhd_graph(point_cloud)
    model._fit_local_views(point_cloud)

    # override the local views using the estimated tangent basis
    model.param.Psi = tang_basis.transpose(0, 2, 1) # emb_dim is the last dimension
    
    c, n_C = model._fit_intermediate_views()
    y = model._fit_global_views(c, n_C)
    return y

# %%
model = rats.RATS(d=emb_dim, k=k_nn, alpha=1, max_iter=5, to_postprocess=False, eta_min=1, to_tear=False)
y_gt = generate_embedding(X, model, gt_estimate['tang_basis'])

# %%
VIS.data(
    y_gt, noise_r, cmap='viridis', figsize=(3,3), save_fn='y_gt', show_axis=False, s=10
)

# %%
model = rats.RATS(d=emb_dim, k=k_nn, alpha=1, max_iter=5, to_postprocess=False, eta_min=1, to_tear=False)
y_lpca = generate_embedding(X, model, lpca_estimate['tang_basis'])

# %%
VIS.data(
    y_lpca, noise_r, cmap='viridis', figsize=(3,3), save_fn='y_lpca', show_axis=False, s=10
)

# %%
model = rats.RATS(d=emb_dim, k=k_nn, alpha=1, max_iter=5, to_postprocess=False, eta_min=1, to_tear=False)
y_lego = generate_embedding(X, model, lego_estimate['tang_basis'])

# %%
VIS.data(
    y_lego, noise_r, cmap='viridis', figsize=(3,3), save_fn='y_lpca', show_axis=False, s=10
)

# %% [markdown]
# # Noise ablation

# %%
max_noise_level = 1
noise_levels = np.linspace(0, max_noise_level, 5)

# %%
error_per_noise_level = {}
for i in range(len(noise_levels)):
    np.random.seed(42)
    noise_i = noise_levels[i] * np.random.uniform(-1, 1, X0.shape[0])
    noise_i = noise_r * noise_i
    X_i = X0 + noise_i[:,None]*normal_dir
    
    lpca_estimate_i = lpca.lpca(X_i, opts = {'emb_dim': emb_dim, 'k_nn': k_nn})
    lego_estimate_i = lego.lego(
        X_i,
        opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad}, 
        gl_opts={'n_eig': n_eig}
    )
    error_per_noise_level[i] = {
        'LPCA': util.tang_basis_estimate_error(lpca_estimate_i['tang_basis'], gt_estimate['tang_basis']),
        'LEGO': util.tang_basis_estimate_error(lego_estimate_i['tang_basis'], gt_estimate['tang_basis']),
    }
# Out:
# [LPCA] Nearest neighbors: 0.0246 s
# [LPCA] Tangent basis estimation: 0.8923 s
# [LPCA] Total execution time: 0.9171 s
#
# [LEGO] Nearest neighbors & diameter: 0.0254 s
# [LEGO] Graph Laplacian spectrum: 0.1974 s
# [LEGO] Gradient first-order approx: 0.0790 s
# [LEGO] Gradient regularization: 0.0088 s
# [LEGO] Tangent basis estimation: 0.9011 s
# [LEGO] Total execution time: 1.2119 s
#
# [LPCA] Nearest neighbors: 0.0243 s
# [LPCA] Tangent basis estimation: 0.8948 s
# [LPCA] Total execution time: 0.9192 s
#
# [LEGO] Nearest neighbors & diameter: 0.0252 s
# [LEGO] Graph Laplacian spectrum: 0.3949 s
# [LEGO] Gradient first-order approx: 0.0794 s
# [LEGO] Gradient regularization: 0.0087 s
# [LEGO] Tangent basis estimation: 0.8997 s
# [LEGO] Total execution time: 1.4080 s
#
# [LPCA] Nearest neighbors: 0.0240 s
# [LPCA] Tangent basis estimation: 0.8986 s
# [LPCA] Total execution time: 0.9226 s
#
# [LEGO] Nearest neighbors & diameter: 0.0251 s
# [LEGO] Graph Laplacian spectrum: 0.2070 s
# [LEGO] Gradient first-order approx: 0.0802 s
# [LEGO] Gradient regularization: 0.0086 s
# [LEGO] Tangent basis estimation: 0.8911 s
# [LEGO] Total execution time: 1.2121 s
#
# [LPCA] Nearest neighbors: 0.0238 s
# [LPCA] Tangent basis estimation: 0.8910 s
# [LPCA] Total execution time: 0.9148 s
#
# [LEGO] Nearest neighbors & diameter: 0.0251 s
# [LEGO] Graph Laplacian spectrum: 0.2094 s
# [LEGO] Gradient first-order approx: 0.0809 s
# [LEGO] Gradient regularization: 0.0087 s
# [LEGO] Tangent basis estimation: 0.8995 s
# [LEGO] Total execution time: 1.2238 s
#
# [LPCA] Nearest neighbors: 0.0247 s
# [LPCA] Tangent basis estimation: 0.8982 s
# [LPCA] Total execution time: 0.9229 s
#
# [LEGO] Nearest neighbors & diameter: 0.0252 s
# [LEGO] Graph Laplacian spectrum: 0.2057 s
# [LEGO] Gradient first-order approx: 0.0801 s
# [LEGO] Gradient regularization: 0.0088 s
# [LEGO] Tangent basis estimation: 0.8932 s
# [LEGO] Total execution time: 1.2132 s

# %%
color = {'LPCA': 'red', 'LEGO': 'blue'}
xticks = VIS.global_distortion_viloinplot_overlay(
    error_per_noise_level, log_scale=False,
    legend=True, filled=True, bbox_to_anchor_=(0, 1.1, 0.3, 0.3), ncol=2,
    prop={'size':14}, loc_='upper left', widths=0.75,
    color = color, remove_annotation=False, offset2=1, offset1=1,
    title='', label='', figsize=(4,3), save_fn='noise_ablation'
)
plt.xticks([0.5, 3.5, 6.5, 9.5, 12.5], [np.round(nl, 4) for nl in noise_levels], fontsize=13)
plt.xlabel('Noise level')
plt.ylabel('Tangent space\n discrepancy')
plt.tight_layout()
plt.savefig(VIS.save_dir + 'noise_ablation_annotated.png', dpi=600)
plt.show()

# %% [markdown]
# # Hyperparameter ablation: varying number of eigenvectors

# %%
n_eig_for_grad_list = np.arange(10, 131, 10).astype('int32')
n_eig_list = (n_eig_for_grad_list > 50) * 100 + 100
X_max_noise_level = X.copy()

# %%
error_per_n_eig = {}
for i in range(len(n_eig_list)):
    n_eig_i = int(n_eig_list[i])
    n_eig_for_grad_i = int(n_eig_for_grad_list[i])
    
    lego_estimate_i = lego.lego(
        X_max_noise_level,
        opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad_i}, 
        gl_opts={'n_eig': n_eig_i}
    )
    

    error_per_n_eig[i] = {
        'LEGO': util.tang_basis_estimate_error(lego_estimate_i['tang_basis'], gt_estimate['tang_basis']),
    }
# Out:
# [LEGO] Nearest neighbors & diameter: 0.0261 s
# [LEGO] Graph Laplacian spectrum: 0.2223 s
# [LEGO] Gradient first-order approx: 0.0795 s
# [LEGO] Gradient regularization: 0.0066 s
# [LEGO] Tangent basis estimation: 0.8949 s
# [LEGO] Total execution time: 1.2295 s
#
# [LEGO] Nearest neighbors & diameter: 0.0258 s
# [LEGO] Graph Laplacian spectrum: 0.2098 s
# [LEGO] Gradient first-order approx: 0.0802 s
# [LEGO] Gradient regularization: 0.0095 s
# [LEGO] Tangent basis estimation: 0.8964 s
# [LEGO] Total execution time: 1.2220 s
#
# [LEGO] Nearest neighbors & diameter: 0.0257 s
# [LEGO] Graph Laplacian spectrum: 0.2098 s
# [LEGO] Gradient first-order approx: 0.0811 s
# [LEGO] Gradient regularization: 0.0117 s
# [LEGO] Tangent basis estimation: 0.9124 s
# [LEGO] Total execution time: 1.2408 s
#
# [LEGO] Nearest neighbors & diameter: 0.0257 s
# [LEGO] Graph Laplacian spectrum: 0.2069 s
# [LEGO] Gradient first-order approx: 0.0830 s
# [LEGO] Gradient regularization: 0.0143 s
# [LEGO] Tangent basis estimation: 0.9206 s
# [LEGO] Total execution time: 1.2508 s
#
# [LEGO] Nearest neighbors & diameter: 0.0256 s
# [LEGO] Graph Laplacian spectrum: 0.2117 s
# [LEGO] Gradient first-order approx: 0.0860 s
# [LEGO] Gradient regularization: 0.0160 s
# [LEGO] Tangent basis estimation: 0.9300 s
# [LEGO] Total execution time: 1.2695 s
#
# [LEGO] Nearest neighbors & diameter: 0.0256 s
# [LEGO] Graph Laplacian spectrum: 0.4435 s
# [LEGO] Gradient first-order approx: 0.0865 s
# [LEGO] Gradient regularization: 0.0234 s
# [LEGO] Tangent basis estimation: 0.9243 s
# [LEGO] Total execution time: 1.5033 s
#
# [LEGO] Nearest neighbors & diameter: 0.0255 s
# [LEGO] Graph Laplacian spectrum: 0.4616 s
# [LEGO] Gradient first-order approx: 0.0883 s
# [LEGO] Gradient regularization: 0.0251 s
# [LEGO] Tangent basis estimation: 0.9331 s
# [LEGO] Total execution time: 1.5338 s
#
# [LEGO] Nearest neighbors & diameter: 0.0258 s
# [LEGO] Graph Laplacian spectrum: 0.4423 s
# [LEGO] Gradient first-order approx: 0.0909 s
# [LEGO] Gradient regularization: 0.0251 s
# [LEGO] Tangent basis estimation: 0.9372 s
# [LEGO] Total execution time: 1.5216 s
#
# [LEGO] Nearest neighbors & diameter: 0.0258 s
# [LEGO] Graph Laplacian spectrum: 0.4555 s
# [LEGO] Gradient first-order approx: 0.0922 s
# [LEGO] Gradient regularization: 0.0348 s
# [LEGO] Tangent basis estimation: 0.9278 s
# [LEGO] Total execution time: 1.5363 s
#
# [LEGO] Nearest neighbors & diameter: 0.0259 s
# [LEGO] Graph Laplacian spectrum: 0.4530 s
# [LEGO] Gradient first-order approx: 0.0934 s
# [LEGO] Gradient regularization: 0.0311 s
# [LEGO] Tangent basis estimation: 0.9481 s
# [LEGO] Total execution time: 1.5517 s
#
# [LEGO] Nearest neighbors & diameter: 0.0258 s
# [LEGO] Graph Laplacian spectrum: 0.4428 s
# [LEGO] Gradient first-order approx: 0.0962 s
# [LEGO] Gradient regularization: 0.0312 s
# [LEGO] Tangent basis estimation: 0.9443 s
# [LEGO] Total execution time: 1.5405 s
#
# [LEGO] Nearest neighbors & diameter: 0.0918 s
# [LEGO] Graph Laplacian spectrum: 0.4418 s
# [LEGO] Gradient first-order approx: 0.1090 s
# [LEGO] Gradient regularization: 0.0349 s
# [LEGO] Tangent basis estimation: 0.9047 s
# [LEGO] Total execution time: 1.5825 s
#
# [LEGO] Nearest neighbors & diameter: 0.0258 s
# [LEGO] Graph Laplacian spectrum: 0.4647 s
# [LEGO] Gradient first-order approx: 0.1012 s
# [LEGO] Gradient regularization: 0.1184 s
# [LEGO] Tangent basis estimation: 0.9270 s
# [LEGO] Total execution time: 1.6373 s

# %%
color = {'LEGO': 'blue'}
xticks = VIS.global_distortion_viloinplot_overlay(
    error_per_n_eig, log_scale=False,
    legend=False, filled=True, widths=0.75,
    color = color, remove_annotation=False, offset2=0, offset1=1,
    title='', label='', figsize=(6,3), save_fn='hyperparam_ablation'
)
xticks_labels = []
for i in range(len(n_eig_list)):
    xticks_labels.append(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
plt.xticks(np.arange(len(n_eig_for_grad_list)), xticks_labels, fontsize=13)
plt.ylabel('Tangent space\n discrepancy')
plt.xlabel('Hyperparameters')
plt.tight_layout()
plt.savefig(VIS.save_dir + 'hyperparam_ablation_annotated.png', dpi=600)
plt.show()

# %%
fig = plt.figure(figsize=(len(n_eig_list)*0.9, 2))
axes = []
for i in range(len(n_eig_list)):
    axes.append(fig.add_subplot(1, len(n_eig_list), i+1, projection='3d'))
    axes[i].view_init(azim=-87, elev=10)

for i in range(len(n_eig_list)):
    plt.subplots_adjust(wspace=0, hspace=0)
    p = axes[i].scatter(*X0.T, c=error_per_n_eig[i]['LEGO'], cmap='hot', vmin=0, vmax=1, s=0.25)
    axes[i].set_title(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
    axes[i].axis('off')
    axes[i].axis('equal')
    
#fig.colorbar(p, ax=axes, orientation='vertical', shrink=0.5)
plt.savefig(VIS.save_dir + '/hyperparam_ablation_error_plotted_on_X.png', dpi=600)

# %% [markdown]
# # Hyperparameter ablation: keeping $m = m_0$

# %%
n_eig_for_grad_list = np.arange(10, 131, 10).astype('int32')
n_eig_list = n_eig_for_grad_list
X_max_noise_level = X.copy()

# %%
error_per_n_eig = {}
for i in range(len(n_eig_list)):
    n_eig_i = int(n_eig_list[i])
    n_eig_for_grad_i = int(n_eig_for_grad_list[i])
    
    lego_estimate_i = lego.lego(
        X_max_noise_level,
        opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad_i}, 
        gl_opts={'n_eig': n_eig_i}
    )
    

    error_per_n_eig[i] = {
        'LEGO': util.tang_basis_estimate_error(lego_estimate_i['tang_basis'], gt_estimate['tang_basis']),
    }
# Out:
# [LEGO] Nearest neighbors & diameter: 0.0268 s
# [LEGO] Graph Laplacian spectrum: 0.0669 s
# [LEGO] Gradient first-order approx: 0.0787 s
# [LEGO] Gradient regularization: 0.0006 s
# [LEGO] Tangent basis estimation: 0.9233 s
# [LEGO] Total execution time: 1.0963 s
#
# [LEGO] Nearest neighbors & diameter: 0.0256 s
# [LEGO] Graph Laplacian spectrum: 0.0831 s
# [LEGO] Gradient first-order approx: 0.0804 s
# [LEGO] Gradient regularization: 0.0016 s
# [LEGO] Tangent basis estimation: 0.9125 s
# [LEGO] Total execution time: 1.1034 s
#
# [LEGO] Nearest neighbors & diameter: 0.0257 s
# [LEGO] Graph Laplacian spectrum: 0.1001 s
# [LEGO] Gradient first-order approx: 0.0819 s
# [LEGO] Gradient regularization: 0.0034 s
# [LEGO] Tangent basis estimation: 0.9189 s
# [LEGO] Total execution time: 1.1301 s
#
# [LEGO] Nearest neighbors & diameter: 0.0253 s
# [LEGO] Graph Laplacian spectrum: 0.1075 s
# [LEGO] Gradient first-order approx: 0.0825 s
# [LEGO] Gradient regularization: 0.0051 s
# [LEGO] Tangent basis estimation: 0.9186 s
# [LEGO] Total execution time: 1.1391 s
#
# [LEGO] Nearest neighbors & diameter: 0.0252 s
# [LEGO] Graph Laplacian spectrum: 0.1271 s
# [LEGO] Gradient first-order approx: 0.0955 s
# [LEGO] Gradient regularization: 0.0065 s
# [LEGO] Tangent basis estimation: 0.9143 s
# [LEGO] Total execution time: 1.1689 s
#
# [LEGO] Nearest neighbors & diameter: 0.0253 s
# [LEGO] Graph Laplacian spectrum: 0.1586 s
# [LEGO] Gradient first-order approx: 0.0855 s
# [LEGO] Gradient regularization: 0.0087 s
# [LEGO] Tangent basis estimation: 0.9143 s
# [LEGO] Total execution time: 1.1925 s
#
# [LEGO] Nearest neighbors & diameter: 0.0254 s
# [LEGO] Graph Laplacian spectrum: 0.1668 s
# [LEGO] Gradient first-order approx: 0.0873 s
# [LEGO] Gradient regularization: 0.0133 s
# [LEGO] Tangent basis estimation: 0.9232 s
# [LEGO] Total execution time: 1.2162 s
#
# [LEGO] Nearest neighbors & diameter: 0.0264 s
# [LEGO] Graph Laplacian spectrum: 0.1865 s
# [LEGO] Gradient first-order approx: 0.0888 s
# [LEGO] Gradient regularization: 0.0185 s
# [LEGO] Tangent basis estimation: 0.9244 s
# [LEGO] Total execution time: 1.2448 s
#
# [LEGO] Nearest neighbors & diameter: 0.0255 s
# [LEGO] Graph Laplacian spectrum: 0.1844 s
# [LEGO] Gradient first-order approx: 0.0931 s
# [LEGO] Gradient regularization: 0.0253 s
# [LEGO] Tangent basis estimation: 0.9411 s
# [LEGO] Total execution time: 1.2697 s
#
# [LEGO] Nearest neighbors & diameter: 0.0255 s
# [LEGO] Graph Laplacian spectrum: 0.2032 s
# [LEGO] Gradient first-order approx: 0.0935 s
# [LEGO] Gradient regularization: 0.0274 s
# [LEGO] Tangent basis estimation: 0.9499 s
# [LEGO] Total execution time: 1.2996 s
#
# [LEGO] Nearest neighbors & diameter: 0.0256 s
# [LEGO] Graph Laplacian spectrum: 0.2229 s
# [LEGO] Gradient first-order approx: 0.0954 s
# [LEGO] Gradient regularization: 0.0259 s
# [LEGO] Tangent basis estimation: 0.9518 s
# [LEGO] Total execution time: 1.3218 s
#
# [LEGO] Nearest neighbors & diameter: 0.0256 s
# [LEGO] Graph Laplacian spectrum: 0.2494 s
# [LEGO] Gradient first-order approx: 0.1038 s
# [LEGO] Gradient regularization: 0.0309 s
# [LEGO] Tangent basis estimation: 0.9371 s
# [LEGO] Total execution time: 1.3470 s
#
# [LEGO] Nearest neighbors & diameter: 0.0258 s
# [LEGO] Graph Laplacian spectrum: 0.2662 s
# [LEGO] Gradient first-order approx: 0.0990 s
# [LEGO] Gradient regularization: 0.0315 s
# [LEGO] Tangent basis estimation: 0.9565 s
# [LEGO] Total execution time: 1.3791 s

# %%
color = {'LEGO': 'blue'}
xticks = VIS.global_distortion_viloinplot_overlay(
    error_per_n_eig, log_scale=False,
    legend=False, filled=True, widths=0.75,
    color = color, remove_annotation=False, offset2=0, offset1=1,
    title='', label='', figsize=(6,3), save_fn='hyperparam_ablation'
)
xticks_labels = []
for i in range(len(n_eig_list)):
    xticks_labels.append(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
plt.xticks(np.arange(len(n_eig_for_grad_list)), xticks_labels, fontsize=13)
plt.ylabel('Tangent space\n discrepancy')
plt.xlabel('Hyperparameters')
plt.tight_layout()
plt.savefig(VIS.save_dir + 'hyperparam_same_m_m0_ablation_annotated.png', dpi=600)
plt.show()

# %%
fig = plt.figure(figsize=(len(n_eig_list)*0.9, 2))
axes = []
for i in range(len(n_eig_list)):
    axes.append(fig.add_subplot(1, len(n_eig_list), i+1, projection='3d'))
    axes[i].view_init(azim=-87, elev=10)

for i in range(len(n_eig_list)):
    plt.subplots_adjust(wspace=0, hspace=0)
    p = axes[i].scatter(*X0.T, c=error_per_n_eig[i]['LEGO'], cmap='hot', vmin=0, vmax=1, s=0.25)
    axes[i].set_title(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
    axes[i].axis('off')
    axes[i].axis('equal')
    
#fig.colorbar(p, ax=axes, orientation='vertical', shrink=0.5)
plt.savefig(VIS.save_dir + '/hyperparam_ablation_error_same_m_m0_plotted_on_X.png', dpi=600)
