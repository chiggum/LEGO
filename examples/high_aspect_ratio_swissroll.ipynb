# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
from matplotlib import pyplot as plt

import datasets_util
import vis_util
import lpca
from lego import lego, util

VIS = vis_util.Visualize('figures/swissroll/')
# Out:
# matplotlib.get_backend() =  inline

# %%
nturns = 6
RES = 100
theta0 = 3*np.pi/2
rmax = 1e-2
X0, labels0 = datasets_util.noisyswissroll(RES=RES, noise=0, nturns=nturns, theta0=theta0, rmax=rmax)
X, labels = datasets_util.noisyswissroll(RES=RES, noise=0.0175, noise_type='ortho-uniform', nturns=nturns, theta0=theta0, rmax=rmax)

# %%
VIS.data(X0, labels0[:,0], cmap='viridis', s=2, figsize=(3,3), colorbar=True, show_axis=False, save_fn='clean_data')

# %%
VIS.data(X, labels0[:,0], cmap='viridis', s=2, azim=-92, elev=-3, figsize=(3,3), show_axis=False, save_fn='noisy_data_side_view')

# %%
# a subsample of points to visualize tangent spaces
n_subsample = 300
np.random.seed(42)
subsample_inds = np.random.choice(np.arange(X.shape[0]), n_subsample, replace=False)

# %%
emb_dim = 2
k_nn = 9

# %% [markdown]
# # LPCA on noiseless data

# %%
gt_estimate = lpca.lpca(X0, opts = {'emb_dim': emb_dim, 'k_nn': k_nn})
# Out:
# [LPCA] Nearest neighbors: 0.0644 s
# [LPCA] Tangent basis estimation: 2.7679 s
# [LPCA] Total execution time: 2.8325 s

# %%
gt_estimate['tang_basis'].shape
# Out:
# (10700, 2, 3)

# %%
VIS.plot_tangent_vectors_2d_in_3d(
    gt_estimate['tang_basis'],
    X0, X0, subsample_inds,
    title='', save_fn='gt_tang_basis'
)

# %% [markdown]
# # LPCA on noisy data

# %%
lpca_estimate = lpca.lpca(X, opts = {'emb_dim': emb_dim, 'k_nn': k_nn})
# Out:
# [LPCA] Nearest neighbors: 0.0631 s
# [LPCA] Tangent basis estimation: 2.7922 s
# [LPCA] Total execution time: 2.8555 s

# %%
VIS.plot_tangent_vectors_2d_in_3d(
    lpca_estimate['tang_basis'],
    X0, X0, subsample_inds,
    title='', save_fn='lpca_tang_basis'
)

# %% [markdown]
# # LEGO on noisy data

# %%
n_eig_for_grad = 40
n_eig = 100
lego_estimate = lego.lego(
    X,
    opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad}, 
    gl_opts={'n_eig': n_eig}
)
# Out:
# [LEGO] Nearest neighbors & diameter: 0.0671 s
# [LEGO] Graph Laplacian spectrum: 1.0792 s
# [LEGO] Gradient first-order approx: 0.2518 s
# [LEGO] Gradient regularization: 0.0264 s
# [LEGO] Tangent basis estimation: 2.7945 s
# [LEGO] Total execution time: 4.2193 s

# %%
VIS.plot_tangent_vectors_2d_in_3d(
    lego_estimate['tang_basis'],
    X0, X0, subsample_inds,
    title='', save_fn='lego_tang_basis'
)

# %% [markdown]
# # Error of LPCA and LEGO estimates

# %%
color = {'lpca': 'red', 'lego': 'green'}
error = {
    'lpca': {'lpca': util.tang_basis_estimate_error(lpca_estimate['tang_basis'], gt_estimate['tang_basis'])},
    'lego': {'lego': util.tang_basis_estimate_error(lego_estimate['tang_basis'], gt_estimate['tang_basis'])},
}

# %%
_ = VIS.global_distortion_viloinplot_overlay(
    error, log_scale=False, legend=False, filled=False,
    color = color, remove_annotation=True, offset2=0, offset1=0,
    title='', label='', figsize=(2,3), save_fn='error_violins'
)

# %%
VIS.compare_principal_angle_discrep(
    X0, [error['lpca']['lpca'], error['lego']['lego']],
    vmin=0, vmax=1, cmap='hot', azim=-87, elev=10, save_fn='lpca_vs_lego_tang_estimate_errors'
)

# %% [markdown]
# # Local intrinsic dimension estimation
#
# We simply change the embedding dimension to be equal to the ambient dimension plot the variance explained in each dimension

# %%
ambient_dim = X.shape[1]

# %%
lpca_estimate_for_lid = lpca.lpca(X, opts = {'emb_dim': ambient_dim, 'k_nn': k_nn})
# Out:
# [LPCA] Nearest neighbors: 0.0651 s
# [LPCA] Tangent basis estimation: 0.2346 s
# [LPCA] Total execution time: 0.2997 s

# %%
VIS.plot_var_exp_violin_plot(
    lpca_estimate_for_lid['var_explained'], color='r', save_fn='lpca_lid_estimate'
)

# %%
lego_estimate_for_lid = lego.lego(
    X,
    opts={'emb_dim': ambient_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad}, 
    gl_opts={'n_eig': n_eig}
)
# Out:
# [LEGO] Nearest neighbors & diameter: 0.0666 s
# [LEGO] Graph Laplacian spectrum: 1.0634 s
# [LEGO] Gradient first-order approx: 0.2435 s
# [LEGO] Gradient regularization: 0.0197 s
# [LEGO] Tangent basis estimation: 0.2625 s
# [LEGO] Total execution time: 1.6558 s

# %%
VIS.plot_var_exp_violin_plot(
    lego_estimate_for_lid['var_explained'], color='b', save_fn='lego_lid_estimate'
)

# %% [markdown]
# # Boundary detection
#
# Note that opts['k_nn'] and opts['k_tune'] set here are specific to boundary detection and has nothing to do with tangent space estimation.
#
# For more details please refer to https://arxiv.org/abs/2411.18942
#
# The source `bx_util.py` is derived from https://github.com/chiggum/robust_boundary_estimation/tree/19f90ff6676e4fe99c417b324431a5e04f15890e

# %%
import sys
import paths_private_
sys.path.insert(0, paths_private_.codebase_path + '/robust_boundary_estimation/src/')
import bx_util

# %%
opts = bx_util.default_opts.copy()
opts['k_nn'] = 128
opts['k_tune'] = 32
opts['local_subspace'] = gt_estimate['tang_basis'].transpose(0, 2, 1) # emb_dim is the last dimension
opts['d'] = 2
gt_bx = bx_util.estimate_bx(X, opts=opts)[0]
# Out:
# 0.0022422680270582944
# 0.00028051369490801045
# 0.00010216831192884167
# 5.838940031965367e-05
# 4.135601947775173e-05
# 3.1799188716067036e-05
# 2.5179184214211255e-05
# 2.0186030285241325e-05
# 1.6924258592061744e-05
# 1.3021319138033328e-05
# 1.00338604796642e-05
# 7.920077747934102e-06
# 5.900154708111252e-06
# 4.5477282445830035e-06
# 3.6635224922094374e-06
# 3.0680906931619878e-06
# 2.7302194066177585e-06
# 2.566631387454491e-06
# 2.28209414579945e-06
# 2.170795319029039e-06
# 1.992687058952481e-06
# 1.808791368543317e-06
# 1.465886400648816e-06
# 1.2938624857358327e-06
# 1.151546661809054e-06
# 9.108056084999372e-07
# h_per_point min max median 0.03481522373306248 0.03516088098579777 0.03491042468294044
# Sinkhorn converged at iter: 16

# %%
opts = bx_util.default_opts.copy()
opts['k_nn'] = 128
opts['k_tune'] = 32
opts['local_subspace'] = lpca_estimate['tang_basis'].transpose(0, 2, 1) # emb_dim is the last dimension
opts['d'] = 2
lpca_bx = bx_util.estimate_bx(X, opts=opts)[0]
# Out:
# 0.0022422680270582944
# 0.00028051369490801045
# 0.00010216831192884167
# 5.838940031965367e-05
# 4.135601947775173e-05
# 3.1799188716067036e-05
# 2.5179184214211255e-05
# 2.0186030285241325e-05
# 1.6924258592061744e-05
# 1.3021319138033328e-05
# 1.00338604796642e-05
# 7.920077747934102e-06
# 5.900154708111252e-06
# 4.5477282445830035e-06
# 3.6635224922094374e-06
# 3.0680906931619878e-06
# 2.7302194066177585e-06
# 2.566631387454491e-06
# 2.28209414579945e-06
# 2.170795319029039e-06
# 1.992687058952481e-06
# 1.808791368543317e-06
# 1.465886400648816e-06
# 1.2938624857358327e-06
# 1.151546661809054e-06
# 9.108056084999372e-07
# h_per_point min max median 0.03481522373306248 0.03516088098579777 0.03491042468294044
# Sinkhorn converged at iter: 16

# %%
opts = bx_util.default_opts.copy()
opts['k_nn'] = 128
opts['k_tune'] = 32
opts['local_subspace'] = lego_estimate['tang_basis'].transpose(0, 2, 1) # emb_dim is the last dimension
opts['d'] = 2
lego_bx = bx_util.estimate_bx(X, opts=opts)[0]
# Out:
# 0.0022422680270582944
# 0.00028051369490801045
# 0.00010216831192884167
# 5.838940031965367e-05
# 4.135601947775173e-05
# 3.1799188716067036e-05
# 2.5179184214211255e-05
# 2.0186030285241325e-05
# 1.6924258592061744e-05
# 1.3021319138033328e-05
# 1.00338604796642e-05
# 7.920077747934102e-06
# 5.900154708111252e-06
# 4.5477282445830035e-06
# 3.6635224922094374e-06
# 3.0680906931619878e-06
# 2.7302194066177585e-06
# 2.566631387454491e-06
# 2.28209414579945e-06
# 2.170795319029039e-06
# 1.992687058952481e-06
# 1.808791368543317e-06
# 1.465886400648816e-06
# 1.2938624857358327e-06
# 1.151546661809054e-06
# 9.108056084999372e-07
# h_per_point min max median 0.03481522373306248 0.03516088098579777 0.03491042468294044
# Sinkhorn converged at iter: 16

# %%
vis_util.plot_detected_boundary(
    X0,
    [gt_bx, lpca_bx, lego_bx],
    ['Ground truth', 'LPCA', 'LEGO'],
    max_prctile = 10, elev=14, azim=-91,
    save_fpath=VIS.save_dir+'/boundaries.png',
    figsize=(8,3)
)

# %% [markdown]
# # Manifold Learning
#
# The source is derived from feature/global-opts branch of https://github.com/Mishne-Lab/pyRATS commit: 8ad44b32a82cd6e52ad6ec17bd8b5917ec037582
#
# Several options are turned off as these may improve the distortion of the low-dimensional local views obtained via projection on the estimated tangent spaces.
#
# - `to_postprocess = False` prevents any postprocessing on local views computed from the tangent space estimates.
# - `eta_min = 1` prevents formation of intermediate views (as they may improve upon local views).
#
# Note that `eta_min = 1` significantly increases the time complexity of the algorithm, however, our main goal here is to evaluate the effect of tangent space estimates on the derived embedding without interference from the remaining components of the algorithm.
#
# We also turned off `to_tear = False` to prevent intentional tearing of the manifold.
#
# For more details please refer to https://www.biorxiv.org/content/10.1101/2024.10.31.621292v2

# %%
import sys
sys.path.insert(0, paths_private_.codebase_path + '/pyRATS/src/')
from pyRATS import rats

def generate_embedding(point_cloud, model, tang_basis):
    model._fit_nbrhd_graph(point_cloud)
    model._fit_local_views(point_cloud)

    # override the local views using the estimated tangent basis
    model.param.Psi = tang_basis.transpose(0, 2, 1) # emb_dim is the last dimension
    
    c, n_C = model._fit_intermediate_views()
    y = model._fit_global_views(c, n_C)
    return y

# %%
model = rats.RATS(d=emb_dim, k=k_nn, alpha=1, max_iter=5, to_postprocess=False, eta_min=1, to_tear=False)
y_gt = generate_embedding(X, model, gt_estimate['tang_basis'])

# %%
VIS.data(
    y_gt, labels[:,0], cmap='viridis', figsize=(3,3), save_fn='y_gt', show_axis=False, s=1,
)

# %%
model = rats.RATS(d=emb_dim, k=k_nn, alpha=1, max_iter=5, to_postprocess=False, eta_min=1, to_tear=False)
y_lpca = generate_embedding(X, model, lpca_estimate['tang_basis'])

# %%
VIS.data(
    y_lpca, labels[:,0], cmap='viridis', figsize=(3,3), save_fn='y_lpca', show_axis=False, s=1
)

# %%
model = rats.RATS(d=emb_dim, k=k_nn, alpha=1, max_iter=5, to_postprocess=False, eta_min=1, to_tear=False)
y_lego = generate_embedding(X, model, lego_estimate['tang_basis'])

# %%
VIS.data(
    y_lego, labels[:,0], cmap='viridis', figsize=(3,3), save_fn='y_lpca', show_axis=False, s=1
)

# %% [markdown]
# # Noise ablation

# %%
max_noise_level = 0.0175
noise_levels = np.linspace(0, 1, 5)

# %%
error_per_noise_level = {}
for i in range(len(noise_levels)):
    X_i, labels_i = datasets_util.noisyswissroll(
        RES=RES, noise=max_noise_level*noise_levels[i], noise_type='ortho-uniform', nturns=nturns, theta0=theta0, rmax=rmax
    )
    lpca_estimate_i = lpca.lpca(X_i, opts = {'emb_dim': emb_dim, 'k_nn': k_nn})
    lego_estimate_i = lego.lego(
        X_i,
        opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad}, 
        gl_opts={'n_eig': n_eig}
    )
    error_per_noise_level[i] = {
        'LPCA': util.tang_basis_estimate_error(lpca_estimate_i['tang_basis'], gt_estimate['tang_basis']),
        'LEGO': util.tang_basis_estimate_error(lego_estimate_i['tang_basis'], gt_estimate['tang_basis']),
    }
# Out:
# [LPCA] Nearest neighbors: 0.0634 s
# [LPCA] Tangent basis estimation: 2.6877 s
# [LPCA] Total execution time: 2.7513 s
#
# [LEGO] Nearest neighbors & diameter: 0.0676 s
# [LEGO] Graph Laplacian spectrum: 1.0254 s
# [LEGO] Gradient first-order approx: 0.2328 s
# [LEGO] Gradient regularization: 0.0214 s
# [LEGO] Tangent basis estimation: 2.7313 s
# [LEGO] Total execution time: 4.0787 s
#
# [LPCA] Nearest neighbors: 0.0722 s
# [LPCA] Tangent basis estimation: 2.6877 s
# [LPCA] Total execution time: 2.7601 s
#
# [LEGO] Nearest neighbors & diameter: 0.0676 s
# [LEGO] Graph Laplacian spectrum: 0.9730 s
# [LEGO] Gradient first-order approx: 0.2496 s
# [LEGO] Gradient regularization: 0.0213 s
# [LEGO] Tangent basis estimation: 2.7352 s
# [LEGO] Total execution time: 4.0469 s
#
# [LPCA] Nearest neighbors: 0.0628 s
# [LPCA] Tangent basis estimation: 2.7265 s
# [LPCA] Total execution time: 2.7894 s
#
# [LEGO] Nearest neighbors & diameter: 0.0663 s
# [LEGO] Graph Laplacian spectrum: 0.9824 s
# [LEGO] Gradient first-order approx: 0.2406 s
# [LEGO] Gradient regularization: 0.0232 s
# [LEGO] Tangent basis estimation: 2.7243 s
# [LEGO] Total execution time: 4.0372 s
#
# [LPCA] Nearest neighbors: 0.0639 s
# [LPCA] Tangent basis estimation: 2.6852 s
# [LPCA] Total execution time: 2.7493 s
#
# [LEGO] Nearest neighbors & diameter: 0.0665 s
# [LEGO] Graph Laplacian spectrum: 1.0256 s
# [LEGO] Gradient first-order approx: 0.2391 s
# [LEGO] Gradient regularization: 0.0214 s
# [LEGO] Tangent basis estimation: 2.7193 s
# [LEGO] Total execution time: 4.0721 s
#
# [LPCA] Nearest neighbors: 0.0630 s
# [LPCA] Tangent basis estimation: 2.6986 s
# [LPCA] Total execution time: 2.7616 s
#
# [LEGO] Nearest neighbors & diameter: 0.0663 s
# [LEGO] Graph Laplacian spectrum: 1.0848 s
# [LEGO] Gradient first-order approx: 0.2384 s
# [LEGO] Gradient regularization: 0.0245 s
# [LEGO] Tangent basis estimation: 2.7230 s
# [LEGO] Total execution time: 4.1374 s

# %%
color = {'LPCA': 'red', 'LEGO': 'blue'}
xticks = VIS.global_distortion_viloinplot_overlay(
    error_per_noise_level, log_scale=False,
    legend=True, filled=True, bbox_to_anchor_=(0, 1.1, 0.3, 0.3), ncol=2,
    prop={'size':14}, loc_='upper left', widths=0.75,
    color = color, remove_annotation=False, offset2=1, offset1=1,
    title='', label='', figsize=(4,3), save_fn='noise_ablation'
)
plt.xticks([0.5, 3.5, 6.5, 9.5, 12.5], [np.round(nl, 4) for nl in noise_levels], fontsize=13)
plt.xlabel('Noise level')
plt.ylabel('Tangent space\n discrepancy')
plt.tight_layout()
plt.savefig(VIS.save_dir + 'noise_ablation_annotated.png', dpi=600)
plt.show()

# %% [markdown]
# # Hyperparameter ablation: varying number of eigenvectors

# %%
n_eig_for_grad_list = np.arange(10, 131, 10).astype('int32')
n_eig_list = (n_eig_for_grad_list > 50) * 100 + 100
X_max_noise_level, _ = datasets_util.noisyswissroll(
    RES=RES, noise=max_noise_level, noise_type='ortho-uniform', nturns=nturns, theta0=theta0, rmax=rmax
)

# %%
error_per_n_eig = {}
for i in range(len(n_eig_list)):
    n_eig_i = int(n_eig_list[i])
    n_eig_for_grad_i = int(n_eig_for_grad_list[i])
    
    lego_estimate_i = lego.lego(
        X_max_noise_level,
        opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad_i}, 
        gl_opts={'n_eig': n_eig_i}
    )
    
    error_per_n_eig[i] = {
        'LEGO': util.tang_basis_estimate_error(lego_estimate_i['tang_basis'], gt_estimate['tang_basis']),
    }
# Out:
# [LEGO] Nearest neighbors & diameter: 0.0670 s
# [LEGO] Graph Laplacian spectrum: 1.0668 s
# [LEGO] Gradient first-order approx: 0.2338 s
# [LEGO] Gradient regularization: 0.0154 s
# [LEGO] Tangent basis estimation: 2.7292 s
# [LEGO] Total execution time: 4.1124 s
#
# [LEGO] Nearest neighbors & diameter: 0.0669 s
# [LEGO] Graph Laplacian spectrum: 1.0464 s
# [LEGO] Gradient first-order approx: 0.2475 s
# [LEGO] Gradient regularization: 0.0175 s
# [LEGO] Tangent basis estimation: 2.7193 s
# [LEGO] Total execution time: 4.0980 s
#
# [LEGO] Nearest neighbors & diameter: 0.0678 s
# [LEGO] Graph Laplacian spectrum: 1.0433 s
# [LEGO] Gradient first-order approx: 0.2380 s
# [LEGO] Gradient regularization: 0.0213 s
# [LEGO] Tangent basis estimation: 2.7580 s
# [LEGO] Total execution time: 4.1286 s
#
# [LEGO] Nearest neighbors & diameter: 0.0671 s
# [LEGO] Graph Laplacian spectrum: 1.0775 s
# [LEGO] Gradient first-order approx: 0.2404 s
# [LEGO] Gradient regularization: 0.0212 s
# [LEGO] Tangent basis estimation: 2.7342 s
# [LEGO] Total execution time: 4.1406 s
#
# [LEGO] Nearest neighbors & diameter: 0.0671 s
# [LEGO] Graph Laplacian spectrum: 1.0493 s
# [LEGO] Gradient first-order approx: 0.2535 s
# [LEGO] Gradient regularization: 0.0257 s
# [LEGO] Tangent basis estimation: 2.7888 s
# [LEGO] Total execution time: 4.1846 s
#
# [LEGO] Nearest neighbors & diameter: 0.0672 s
# [LEGO] Graph Laplacian spectrum: 1.8056 s
# [LEGO] Gradient first-order approx: 0.2447 s
# [LEGO] Gradient regularization: 0.0756 s
# [LEGO] Tangent basis estimation: 2.7998 s
# [LEGO] Total execution time: 4.9931 s
#
# [LEGO] Nearest neighbors & diameter: 0.0674 s
# [LEGO] Graph Laplacian spectrum: 1.8257 s
# [LEGO] Gradient first-order approx: 0.2492 s
# [LEGO] Gradient regularization: 0.0409 s
# [LEGO] Tangent basis estimation: 2.8165 s
# [LEGO] Total execution time: 4.9999 s
#
# [LEGO] Nearest neighbors & diameter: 0.0672 s
# [LEGO] Graph Laplacian spectrum: 1.7941 s
# [LEGO] Gradient first-order approx: 0.2518 s
# [LEGO] Gradient regularization: 0.0454 s
# [LEGO] Tangent basis estimation: 2.7769 s
# [LEGO] Total execution time: 4.9356 s
#
# [LEGO] Nearest neighbors & diameter: 0.0670 s
# [LEGO] Graph Laplacian spectrum: 1.7877 s
# [LEGO] Gradient first-order approx: 0.2556 s
# [LEGO] Gradient regularization: 0.0521 s
# [LEGO] Tangent basis estimation: 2.8224 s
# [LEGO] Total execution time: 4.9851 s
#
# [LEGO] Nearest neighbors & diameter: 0.0670 s
# [LEGO] Graph Laplacian spectrum: 1.8486 s
# [LEGO] Gradient first-order approx: 0.2580 s
# [LEGO] Gradient regularization: 0.0539 s
# [LEGO] Tangent basis estimation: 2.8007 s
# [LEGO] Total execution time: 5.0285 s
#
# [LEGO] Nearest neighbors & diameter: 0.0809 s
# [LEGO] Graph Laplacian spectrum: 1.8236 s
# [LEGO] Gradient first-order approx: 0.2615 s
# [LEGO] Gradient regularization: 0.0564 s
# [LEGO] Tangent basis estimation: 2.7616 s
# [LEGO] Total execution time: 4.9842 s
#
# [LEGO] Nearest neighbors & diameter: 0.0678 s
# [LEGO] Graph Laplacian spectrum: 1.7694 s
# [LEGO] Gradient first-order approx: 0.2693 s
# [LEGO] Gradient regularization: 0.0608 s
# [LEGO] Tangent basis estimation: 2.8403 s
# [LEGO] Total execution time: 5.0078 s
#
# [LEGO] Nearest neighbors & diameter: 0.0674 s
# [LEGO] Graph Laplacian spectrum: 1.8161 s
# [LEGO] Gradient first-order approx: 0.2753 s
# [LEGO] Gradient regularization: 0.0602 s
# [LEGO] Tangent basis estimation: 2.8203 s
# [LEGO] Total execution time: 5.0396 s

# %%
color = {'LEGO': 'blue'}
xticks = VIS.global_distortion_viloinplot_overlay(
    error_per_n_eig, log_scale=False,
    legend=False, filled=True, widths=0.75,
    color = color, remove_annotation=False, offset2=0, offset1=1,
    title='', label='', figsize=(6,3), save_fn='hyperparam_ablation'
)
xticks_labels = []
for i in range(len(n_eig_list)):
    xticks_labels.append(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
plt.xticks(np.arange(len(n_eig_for_grad_list)), xticks_labels, fontsize=13)
plt.ylabel('Tangent space\n discrepancy')
plt.xlabel('Hyperparameters')
plt.tight_layout()
plt.savefig(VIS.save_dir + 'hyperparam_ablation_annotated.png', dpi=600)
plt.show()

# %%
fig = plt.figure(figsize=(len(n_eig_list)*0.9, 2))
axes = []
for i in range(len(n_eig_list)):
    axes.append(fig.add_subplot(1, len(n_eig_list), i+1, projection='3d'))
    axes[i].view_init(azim=-87, elev=10)

for i in range(len(n_eig_list)):
    plt.subplots_adjust(wspace=0, hspace=0)
    p = axes[i].scatter(*X0.T, c=error_per_n_eig[i]['LEGO'], cmap='hot', vmin=0, vmax=1, s=0.25)
    axes[i].set_title(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
    axes[i].axis('off')
    axes[i].axis('equal')
    
#fig.colorbar(p, ax=axes, orientation='vertical', shrink=0.5)
plt.savefig(VIS.save_dir + '/hyperparam_ablation_error_plotted_on_X.png', dpi=600)

# %% [markdown]
# # Hyperparameter ablation: $m=m_0$

# %%
n_eig_for_grad_list = np.arange(10, 131, 10).astype('int32')
n_eig_list = n_eig_for_grad_list
X_max_noise_level, _ = datasets_util.noisyswissroll(
    RES=RES, noise=max_noise_level, noise_type='ortho-uniform', nturns=nturns, theta0=theta0, rmax=rmax
)

# %%
error_per_n_eig = {}
for i in range(len(n_eig_list)):
    n_eig_i = int(n_eig_list[i])
    n_eig_for_grad_i = int(n_eig_for_grad_list[i])
    
    lego_estimate_i = lego.lego(
        X_max_noise_level,
        opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad_i}, 
        gl_opts={'n_eig': n_eig_i}
    )
    
    error_per_n_eig[i] = {
        'LEGO': util.tang_basis_estimate_error(lego_estimate_i['tang_basis'], gt_estimate['tang_basis']),
    }
# Out:
# [LEGO] Nearest neighbors & diameter: 0.0677 s
# [LEGO] Graph Laplacian spectrum: 0.2033 s
# [LEGO] Gradient first-order approx: 0.2328 s
# [LEGO] Gradient regularization: 0.0024 s
# [LEGO] Tangent basis estimation: 2.7992 s
# [LEGO] Total execution time: 3.3058 s
#
# [LEGO] Nearest neighbors & diameter: 0.0671 s
# [LEGO] Graph Laplacian spectrum: 0.2352 s
# [LEGO] Gradient first-order approx: 0.2394 s
# [LEGO] Gradient regularization: 0.0063 s
# [LEGO] Tangent basis estimation: 2.7801 s
# [LEGO] Total execution time: 3.3285 s
#
# [LEGO] Nearest neighbors & diameter: 0.0668 s
# [LEGO] Graph Laplacian spectrum: 0.4490 s
# [LEGO] Gradient first-order approx: 0.2522 s
# [LEGO] Gradient regularization: 0.0146 s
# [LEGO] Tangent basis estimation: 2.7997 s
# [LEGO] Total execution time: 3.5826 s
#
# [LEGO] Nearest neighbors & diameter: 0.0678 s
# [LEGO] Graph Laplacian spectrum: 0.5208 s
# [LEGO] Gradient first-order approx: 0.2436 s
# [LEGO] Gradient regularization: 0.0156 s
# [LEGO] Tangent basis estimation: 2.7641 s
# [LEGO] Total execution time: 3.6121 s
#
# [LEGO] Nearest neighbors & diameter: 0.0670 s
# [LEGO] Graph Laplacian spectrum: 0.5256 s
# [LEGO] Gradient first-order approx: 0.2469 s
# [LEGO] Gradient regularization: 0.0221 s
# [LEGO] Tangent basis estimation: 2.8495 s
# [LEGO] Total execution time: 3.7114 s
#
# [LEGO] Nearest neighbors & diameter: 0.0669 s
# [LEGO] Graph Laplacian spectrum: 0.4954 s
# [LEGO] Gradient first-order approx: 0.2582 s
# [LEGO] Gradient regularization: 0.0222 s
# [LEGO] Tangent basis estimation: 2.7969 s
# [LEGO] Total execution time: 3.6398 s
#
# [LEGO] Nearest neighbors & diameter: 0.0671 s
# [LEGO] Graph Laplacian spectrum: 0.5771 s
# [LEGO] Gradient first-order approx: 0.2571 s
# [LEGO] Gradient regularization: 0.0256 s
# [LEGO] Tangent basis estimation: 2.8383 s
# [LEGO] Total execution time: 3.7654 s
#
# [LEGO] Nearest neighbors & diameter: 0.0671 s
# [LEGO] Graph Laplacian spectrum: 0.6616 s
# [LEGO] Gradient first-order approx: 0.2595 s
# [LEGO] Gradient regularization: 0.0309 s
# [LEGO] Tangent basis estimation: 2.8055 s
# [LEGO] Total execution time: 3.8249 s
#
# [LEGO] Nearest neighbors & diameter: 0.0674 s
# [LEGO] Graph Laplacian spectrum: 0.7504 s
# [LEGO] Gradient first-order approx: 0.2614 s
# [LEGO] Gradient regularization: 0.0376 s
# [LEGO] Tangent basis estimation: 2.8126 s
# [LEGO] Total execution time: 3.9298 s
#
# [LEGO] Nearest neighbors & diameter: 0.0672 s
# [LEGO] Graph Laplacian spectrum: 1.0309 s
# [LEGO] Gradient first-order approx: 0.2699 s
# [LEGO] Gradient regularization: 0.0381 s
# [LEGO] Tangent basis estimation: 2.8439 s
# [LEGO] Total execution time: 4.2504 s
#
# [LEGO] Nearest neighbors & diameter: 0.0669 s
# [LEGO] Graph Laplacian spectrum: 1.1821 s
# [LEGO] Gradient first-order approx: 0.2793 s
# [LEGO] Gradient regularization: 0.0441 s
# [LEGO] Tangent basis estimation: 2.8600 s
# [LEGO] Total execution time: 4.4327 s
#
# [LEGO] Nearest neighbors & diameter: 0.0670 s
# [LEGO] Graph Laplacian spectrum: 1.0279 s
# [LEGO] Gradient first-order approx: 0.2758 s
# [LEGO] Gradient regularization: 0.0468 s
# [LEGO] Tangent basis estimation: 2.8619 s
# [LEGO] Total execution time: 4.2796 s
#
# [LEGO] Nearest neighbors & diameter: 0.0675 s
# [LEGO] Graph Laplacian spectrum: 1.0825 s
# [LEGO] Gradient first-order approx: 0.2790 s
# [LEGO] Gradient regularization: 0.0533 s
# [LEGO] Tangent basis estimation: 2.8494 s
# [LEGO] Total execution time: 4.3320 s

# %%
color = {'LEGO': 'blue'}
xticks = VIS.global_distortion_viloinplot_overlay(
    error_per_n_eig, log_scale=False,
    legend=False, filled=True, widths=0.75,
    color = color, remove_annotation=False, offset2=0, offset1=1,
    title='', label='', figsize=(6,3), save_fn='hyperparam_ablation'
)
xticks_labels = []
for i in range(len(n_eig_list)):
    xticks_labels.append(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
plt.xticks(np.arange(len(n_eig_for_grad_list)), xticks_labels, fontsize=13)
plt.ylabel('Tangent space\n discrepancy')
plt.xlabel('Hyperparameters')
plt.tight_layout()
plt.savefig(VIS.save_dir + 'hyperparam_ablation_same_m_m0_annotated.png', dpi=600)
plt.show()

# %%
fig = plt.figure(figsize=(len(n_eig_list)*0.9, 2))
axes = []
for i in range(len(n_eig_list)):
    axes.append(fig.add_subplot(1, len(n_eig_list), i+1, projection='3d'))
    axes[i].view_init(azim=-87, elev=10)

for i in range(len(n_eig_list)):
    plt.subplots_adjust(wspace=0, hspace=0)
    p = axes[i].scatter(*X0.T, c=error_per_n_eig[i]['LEGO'], cmap='hot', vmin=0, vmax=1, s=0.25)
    axes[i].set_title(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
    axes[i].axis('off')
    axes[i].axis('equal')
    
#fig.colorbar(p, ax=axes, orientation='vertical', shrink=0.5)
plt.savefig(VIS.save_dir + '/hyperparam_ablation_error_same_m_m0__plotted_on_X.png', dpi=600)

# %% [markdown]
# # ISOMAP embeddings

# %%
from sklearn.manifold import Isomap
isomap_n_neighbors = [5, 8, 9, 10, 25]
for n_neighbors in isomap_n_neighbors:
    print('n_neighbors:', n_neighbors, flush=True)
    isomap_obj = Isomap(n_neighbors=n_neighbors, n_components=emb_dim, n_jobs=-1)
    y = isomap_obj.fit_transform(X)
    VIS.data(y, labels[:,0], cmap='viridis', figsize=(3,3), show_axis=False)
    plt.show()
# Out:
# n_neighbors: 5
# n_neighbors: 8
# n_neighbors: 9
# n_neighbors: 10
# n_neighbors: 25
