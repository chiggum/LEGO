# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.insert(0, '../../')

# %%
import numpy as np
from matplotlib import pyplot as plt

import datasets_util
import vis_util
import lpca
from lego import lego, util

VIS = vis_util.Visualize('figures/truncated_torus_non_uniform_density_and_noise/')
# Out:
# matplotlib.get_backend() =  inline

# %%
X0_, labels0_, gt_tang_basis, normal_dir_ = datasets_util.curvedtorus3d_with_normal_dir(n=10000, density='non-uniform')

# %%
# truncate the torus
x_max = 0.14
mask = (X0_[:,0] < x_max) & (X0_[:,2] < 0)
X0 = X0_[mask,:]
labels0 = labels0_[mask,:]
gt_tang_basis = gt_tang_basis[mask,:]
normal_dir = normal_dir_[mask,:]

# %%
theta = labels0[:,0]

# %%
np.random.seed(42)
noise_r = 0.01 + 0.03*(1+np.cos(2*theta))/2
noise = np.random.normal(0, 1, X0.shape[0])
noise = noise_r*noise
X = X0 + noise[:,None]*normal_dir

# %%
labels = labels0

# %%
VIS.data(
    X0, noise_r, elev=26, azim=-42,
    cmap='viridis', colorbar=True, title='',
    save_fn='clean_data', figsize=(5,5),
    show_axis=False, axis_image=True
)

# %%
VIS.data(
    X, noise_r, elev=26, azim=-42,
    cmap='viridis', colorbar=True, title='',
    save_fn='noisy_data', figsize=(5,5),
    show_axis=False, axis_image=True
)

# %%
# a subsample of points to visualize tangent spaces
n_subsample = 200
np.random.seed(42)
subsample_inds = np.random.choice(np.arange(X.shape[0]), n_subsample, replace=False)

# %%
emb_dim = 2
k_nn = 14

# %% [markdown]
# # LPCA on noiseless data

# %%
gt_estimate = {
    'tang_basis': gt_tang_basis
}

# %%
gt_estimate['tang_basis'].shape
# Out:
# (3362, 2, 3)

# %%
VIS.plot_tangent_vectors_2d_in_3d(
    gt_estimate['tang_basis'],
    X0, X0, subsample_inds,
    title='', save_fn='gt_tang_basis'
)

# %% [markdown]
# # LPCA on noisy data

# %%
lpca_estimate = lpca.lpca(X, opts = {'emb_dim': emb_dim, 'k_nn': k_nn})
# Out:
# [LPCA] Nearest neighbors: 0.0267 s
# [LPCA] Tangent basis estimation: 0.8990 s
# [LPCA] Total execution time: 0.9257 s

# %%
VIS.plot_tangent_vectors_2d_in_3d(
    lpca_estimate['tang_basis'],
    X0, X0, subsample_inds,
    title='', save_fn='lpca_tang_basis'
)

# %% [markdown]
# # LEGO on noisy data

# %%
n_eig_for_grad = 20
n_eig = 100
lego_estimate = lego.lego(
    X,
    opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad}, 
    gl_opts={'n_eig': n_eig}
)
# Out:
# [LEGO] Diameter normalization & Nearest neighbors: 0.0258 s
# [LEGO] Graph Laplacian spectrum: 0.3991 s
# [LEGO] Gradient first-order approx: 0.0846 s
# [LEGO] Gradient regularization: 0.3448 s
# [LEGO] Tangent basis estimation: 0.8802 s
# [LEGO] Total execution time: 1.7350 s

# %%
VIS.plot_tangent_vectors_2d_in_3d(
    lego_estimate['tang_basis'],
    X0, X0, subsample_inds,
    title='', save_fn='lego_tang_basis'
)

# %% [markdown]
# # Error of LPCA and LEGO estimates

# %%
color = {'lpca': 'red', 'lego': 'green'}
error = {
    'lpca': {'lpca': util.tang_basis_estimate_error(lpca_estimate['tang_basis'], gt_estimate['tang_basis'])},
    'lego': {'lego': util.tang_basis_estimate_error(lego_estimate['tang_basis'], gt_estimate['tang_basis'])},
}

# %%
_ = VIS.global_distortion_viloinplot_overlay(
    error, log_scale=False, legend=False, filled=False,
    color = color, remove_annotation=True, offset2=0, offset1=0,
    title='', label='', figsize=(2,3), save_fn='error_violins'
)

# %%
VIS.compare_principal_angle_discrep(
    X0, [error['lpca']['lpca'], error['lego']['lego']],
    vmin=0, vmax=1, cmap='hot', save_fn='lpca_vs_lego_tang_estimate_errors'
)

# %% [markdown]
# # Local intrinsic dimension estimation
#
# We simply change the embedding dimension to be equal to the ambient dimension plot the variance explained in each dimension

# %%
ambient_dim = X.shape[1]

# %%
lego_estimate_for_lid = lego.lego(
    X,
    opts={'emb_dim': ambient_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad}, 
    gl_opts={'n_eig': n_eig}
)
# Out:
# [LEGO] Diameter normalization & Nearest neighbors: 0.0270 s
# [LEGO] Graph Laplacian spectrum: 0.3876 s
# [LEGO] Gradient first-order approx: 0.0831 s
# [LEGO] Gradient regularization: 0.1037 s
# [LEGO] Tangent basis estimation: 0.0845 s
# [LEGO] Total execution time: 0.6862 s

# %%
VIS.plot_var_exp_violin_plot(
    lego_estimate_for_lid['var_explained'], color='b', save_fn='lego_lid_estimate'
)

# %% [markdown]
# # Boundary detection
#
# Note that opts['k_nn'] and opts['k_tune'] set here are specific to boundary detection and has nothing to do with tangent space estimation.
#
# For more details please refer to https://arxiv.org/abs/2411.18942
#
# The source `bx_util.py` is derived from https://github.com/chiggum/robust_boundary_estimation/tree/19f90ff6676e4fe99c417b324431a5e04f15890e

# %%
import sys
import paths_private_
sys.path.insert(0, paths_private_.codebase_path + '/robust_boundary_estimation/src/')
import bx_util

# %%
opts = bx_util.default_opts.copy()
opts['k_nn'] = 128
opts['k_tune'] = 32
opts['local_subspace'] = lego_estimate['tang_basis'].transpose(0, 2, 1) # emb_dim is the last dimension
opts['d'] = 2
lego_bx = bx_util.estimate_bx(X, opts=opts)[0]
# Out:
# 0.006178909023209997
# 0.0012273322761835559
# 0.0005491245855296102
# 0.0003029740884853513
# 0.00018318685397228048
# 0.00011041364314763739
# 7.310826955712001e-05
# 6.0007772726424185e-05
# 5.735433025651583e-05
# 3.9122463258518795e-05
# 3.057297983071156e-05
# 2.260918070916485e-05
# 1.921833495338525e-05
# 1.0602172593255459e-05
# 8.9380546513184e-06
# 9.346330534552121e-06
# 6.061446345030677e-06
# 3.632245729398202e-06
# 4.023353842282819e-06
# 4.336488418710441e-06
# 3.7254166278780774e-06
# 3.942504458914372e-06
# 2.9933524539060222e-06
# 2.8063768841917136e-06
# 2.4197567599900914e-06
# 2.1213243746004867e-06
# 1.8596501710334126e-06
# 2.0475040474132083e-06
# 2.3101629417943865e-06
# 3.2237774466376537e-06
# h_per_point min max median 0.036015358828718425 0.03846880669437846 0.03712493454693535
# Sinkhorn converged at iter: 45

# %%
vis_util.plot_detected_boundary(
    X0[:,:2],
    [lego_bx],
    ['LEGO'],
    max_prctile = 14, figsize=(2.5,2.5), s=5,
    save_fpath=VIS.save_dir+'/boundaries.png'
)

# %% [markdown]
# # Manifold Learning
#
# The source is derived from feature/global-opts branch of https://github.com/Mishne-Lab/pyRATS commit: 8ad44b32a82cd6e52ad6ec17bd8b5917ec037582
#
# Several options are turned off as these may improve the distortion of the low-dimensional local views obtained via projection on the estimated tangent spaces.
#
# - `to_postprocess = False` prevents any postprocessing on local views computed from the tangent space estimates.
# - `eta_min = 1` prevents formation of intermediate views (as they may improve upon local views).
#
# Note that `eta_min = 1` significantly increases the time complexity of the algorithm, however, our main goal here is to evaluate the effect of tangent space estimates on the derived embedding without interference from the remaining components of the algorithm.
#
# We also turned off `to_tear = False` to prevent intentional tearing of the manifold.
#
# For more details please refer to https://www.biorxiv.org/content/10.1101/2024.10.31.621292v2

# %%
import sys
import paths_private_
sys.path.insert(0, paths_private_.codebase_path + '/pyRATS/src/')
from pyRATS import rats

def generate_embedding(point_cloud, model, tang_basis):
    model._fit_nbrhd_graph(point_cloud)
    model._fit_local_views(point_cloud)

    # override the local views using the estimated tangent basis
    model.param.Psi = tang_basis.transpose(0, 2, 1) # emb_dim is the last dimension
    
    c, n_C = model._fit_intermediate_views()
    y = model._fit_global_views(c, n_C)
    return y

# %%
model = rats.RATS(d=emb_dim, k=k_nn, alpha=1, max_iter=5, to_postprocess=False, eta_min=1, to_tear=False)
y_lego = generate_embedding(X, model, lego_estimate['tang_basis'])

# %%
VIS.data(
    y_lego, noise_r, cmap='viridis', figsize=(3,3), save_fn='y_lpca', show_axis=False, s=10
)

# %% [markdown]
# # Noise ablation

# %%
max_noise_level = 1
noise_levels = np.linspace(0, max_noise_level, 5)

# %%
error_per_noise_level = {}
for i in range(len(noise_levels)):
    np.random.seed(42)
    noise_i = noise_levels[i] * np.random.normal(0, 1, X0.shape[0])
    noise_i = noise_r * noise_i
    X_i = X0 + noise_i[:,None]*normal_dir
    
    lpca_estimate_i = lpca.lpca(X_i, opts = {'emb_dim': emb_dim, 'k_nn': k_nn})
    lego_estimate_i = lego.lego(
        X_i,
        opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad}, 
        gl_opts={'n_eig': n_eig}
    )
    error_per_noise_level[i] = {
        'LPCA': util.tang_basis_estimate_error(lpca_estimate_i['tang_basis'], gt_estimate['tang_basis']),
        'LEGO': util.tang_basis_estimate_error(lego_estimate_i['tang_basis'], gt_estimate['tang_basis']),
    }
# Out:
# [LPCA] Nearest neighbors: 0.0255 s
# [LPCA] Tangent basis estimation: 0.8704 s
# [LPCA] Total execution time: 0.8960 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0237 s
# [LEGO] Graph Laplacian spectrum: 0.3741 s
# [LEGO] Gradient first-order approx: 0.0808 s
# [LEGO] Gradient regularization: 0.1604 s
# [LEGO] Tangent basis estimation: 0.8774 s
# [LEGO] Total execution time: 1.5167 s
#
# [LPCA] Nearest neighbors: 0.0242 s
# [LPCA] Tangent basis estimation: 0.8754 s
# [LPCA] Total execution time: 0.8997 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0248 s
# [LEGO] Graph Laplacian spectrum: 0.4871 s
# [LEGO] Gradient first-order approx: 0.0828 s
# [LEGO] Gradient regularization: 0.1363 s
# [LEGO] Tangent basis estimation: 0.8724 s
# [LEGO] Total execution time: 1.6037 s
#
# [LPCA] Nearest neighbors: 0.0257 s
# [LPCA] Tangent basis estimation: 0.8716 s
# [LPCA] Total execution time: 0.8975 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0255 s
# [LEGO] Graph Laplacian spectrum: 0.2393 s
# [LEGO] Gradient first-order approx: 0.0921 s
# [LEGO] Gradient regularization: 0.1679 s
# [LEGO] Tangent basis estimation: 0.8683 s
# [LEGO] Total execution time: 1.3934 s
#
# [LPCA] Nearest neighbors: 0.0244 s
# [LPCA] Tangent basis estimation: 0.8676 s
# [LPCA] Total execution time: 0.8920 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0240 s
# [LEGO] Graph Laplacian spectrum: 0.3798 s
# [LEGO] Gradient first-order approx: 0.0822 s
# [LEGO] Gradient regularization: 0.1803 s
# [LEGO] Tangent basis estimation: 0.8714 s
# [LEGO] Total execution time: 1.5379 s
#
# [LPCA] Nearest neighbors: 0.0257 s
# [LPCA] Tangent basis estimation: 0.8776 s
# [LPCA] Total execution time: 0.9034 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0250 s
# [LEGO] Graph Laplacian spectrum: 0.4644 s
# [LEGO] Gradient first-order approx: 0.0827 s
# [LEGO] Gradient regularization: 0.1879 s
# [LEGO] Tangent basis estimation: 0.8808 s
# [LEGO] Total execution time: 1.6410 s

# %%
color = {'LPCA': 'red', 'LEGO': 'blue'}
xticks = VIS.global_distortion_viloinplot_overlay(
    error_per_noise_level, log_scale=False,
    legend=True, filled=True, bbox_to_anchor_=(0, 1.1, 0.3, 0.3), ncol=2,
    prop={'size':14}, loc_='upper left', widths=0.75,
    color = color, remove_annotation=False, offset2=1, offset1=1,
    title='', label='', figsize=(4,3), save_fn='noise_ablation'
)
plt.xticks([0.5, 3.5, 6.5, 9.5, 12.5], [np.round(nl, 4) for nl in noise_levels], fontsize=13)
plt.xlabel('Noise level')
plt.ylabel('Tangent space\n discrepancy')
plt.tight_layout()
plt.savefig(VIS.save_dir + 'noise_ablation_annotated.png', dpi=600)
plt.show()

# %% [markdown]
# # Hyperparameter ablation: varying number of eigenvectors

# %%
n_eig_for_grad_list = np.arange(10, 131, 10).astype('int32')
n_eig_list = (n_eig_for_grad_list > 50) * 100 + 100
X_max_noise_level = X.copy()

# %%
error_per_n_eig = {}
for i in range(len(n_eig_list)):
    n_eig_i = int(n_eig_list[i])
    n_eig_for_grad_i = int(n_eig_for_grad_list[i])
    
    lego_estimate_i = lego.lego(
        X_max_noise_level,
        opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad_i}, 
        gl_opts={'n_eig': n_eig_i}
    )
    

    error_per_n_eig[i] = {
        'LEGO': util.tang_basis_estimate_error(lego_estimate_i['tang_basis'], gt_estimate['tang_basis']),
    }
# Out:
# [LEGO] Diameter normalization & Nearest neighbors: 0.0253 s
# [LEGO] Graph Laplacian spectrum: 0.3448 s
# [LEGO] Gradient first-order approx: 0.0809 s
# [LEGO] Gradient regularization: 0.1133 s
# [LEGO] Tangent basis estimation: 0.8793 s
# [LEGO] Total execution time: 1.4439 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0251 s
# [LEGO] Graph Laplacian spectrum: 0.3665 s
# [LEGO] Gradient first-order approx: 0.0833 s
# [LEGO] Gradient regularization: 0.0863 s
# [LEGO] Tangent basis estimation: 0.8752 s
# [LEGO] Total execution time: 1.4365 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0245 s
# [LEGO] Graph Laplacian spectrum: 0.3004 s
# [LEGO] Gradient first-order approx: 0.0829 s
# [LEGO] Gradient regularization: 0.1055 s
# [LEGO] Tangent basis estimation: 0.8803 s
# [LEGO] Total execution time: 1.3940 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0246 s
# [LEGO] Graph Laplacian spectrum: 0.2801 s
# [LEGO] Gradient first-order approx: 0.0940 s
# [LEGO] Gradient regularization: 0.1901 s
# [LEGO] Tangent basis estimation: 0.8764 s
# [LEGO] Total execution time: 1.4655 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0252 s
# [LEGO] Graph Laplacian spectrum: 0.2953 s
# [LEGO] Gradient first-order approx: 0.0866 s
# [LEGO] Gradient regularization: 0.0213 s
# [LEGO] Tangent basis estimation: 0.8981 s
# [LEGO] Total execution time: 1.3267 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0245 s
# [LEGO] Graph Laplacian spectrum: 0.5553 s
# [LEGO] Gradient first-order approx: 0.0885 s
# [LEGO] Gradient regularization: 0.0419 s
# [LEGO] Tangent basis estimation: 0.8991 s
# [LEGO] Total execution time: 1.6094 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0251 s
# [LEGO] Graph Laplacian spectrum: 0.7131 s
# [LEGO] Gradient first-order approx: 0.0911 s
# [LEGO] Gradient regularization: 0.1855 s
# [LEGO] Tangent basis estimation: 0.8919 s
# [LEGO] Total execution time: 1.9069 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0251 s
# [LEGO] Graph Laplacian spectrum: 0.5409 s
# [LEGO] Gradient first-order approx: 0.0921 s
# [LEGO] Gradient regularization: 0.0538 s
# [LEGO] Tangent basis estimation: 0.8917 s
# [LEGO] Total execution time: 1.6039 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0247 s
# [LEGO] Graph Laplacian spectrum: 0.5419 s
# [LEGO] Gradient first-order approx: 0.0946 s
# [LEGO] Gradient regularization: 0.2629 s
# [LEGO] Tangent basis estimation: 0.9087 s
# [LEGO] Total execution time: 1.8332 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0249 s
# [LEGO] Graph Laplacian spectrum: 0.8593 s
# [LEGO] Gradient first-order approx: 0.1072 s
# [LEGO] Gradient regularization: 0.3185 s
# [LEGO] Tangent basis estimation: 0.8903 s
# [LEGO] Total execution time: 2.2005 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0253 s
# [LEGO] Graph Laplacian spectrum: 0.8933 s
# [LEGO] Gradient first-order approx: 0.0998 s
# [LEGO] Gradient regularization: 0.1965 s
# [LEGO] Tangent basis estimation: 0.9084 s
# [LEGO] Total execution time: 2.1236 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0262 s
# [LEGO] Graph Laplacian spectrum: 0.6581 s
# [LEGO] Gradient first-order approx: 0.0999 s
# [LEGO] Gradient regularization: 0.1131 s
# [LEGO] Tangent basis estimation: 0.9121 s
# [LEGO] Total execution time: 1.8097 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0248 s
# [LEGO] Graph Laplacian spectrum: 0.8725 s
# [LEGO] Gradient first-order approx: 0.1019 s
# [LEGO] Gradient regularization: 0.4019 s
# [LEGO] Tangent basis estimation: 0.9031 s
# [LEGO] Total execution time: 2.3045 s

# %%
color = {'LEGO': 'blue'}
xticks = VIS.global_distortion_viloinplot_overlay(
    error_per_n_eig, log_scale=False,
    legend=False, filled=True, widths=0.75,
    color = color, remove_annotation=False, offset2=0, offset1=1,
    title='', label='', figsize=(6,3), save_fn='hyperparam_ablation'
)
xticks_labels = []
for i in range(len(n_eig_list)):
    xticks_labels.append(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
plt.xticks(np.arange(len(n_eig_for_grad_list)), xticks_labels, fontsize=13)
plt.ylabel('Tangent space\n discrepancy')
plt.xlabel('Hyperparameters')
plt.tight_layout()
plt.savefig(VIS.save_dir + 'hyperparam_ablation_annotated.png', dpi=600)
plt.show()

# %%
fig = plt.figure(figsize=(len(n_eig_list)*0.9, 2))
axes = []
for i in range(len(n_eig_list)):
    axes.append(fig.add_subplot(1, len(n_eig_list), i+1, projection='3d'))
    axes[i].view_init(azim=-87, elev=10)

for i in range(len(n_eig_list)):
    plt.subplots_adjust(wspace=0, hspace=0)
    p = axes[i].scatter(*X0.T, c=error_per_n_eig[i]['LEGO'], cmap='hot', vmin=0, vmax=1, s=0.25)
    axes[i].set_title(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
    axes[i].axis('off')
    axes[i].axis('equal')
    
#fig.colorbar(p, ax=axes, orientation='vertical', shrink=0.5)
plt.savefig(VIS.save_dir + '/hyperparam_ablation_error_plotted_on_X.png', dpi=600)

# %%
# %matplotlib widget
fig = plt.figure(figsize=(len(n_eig_list)*0.9, 2))
axes = []
for i in range(len(n_eig_list)):
    axes.append(fig.add_subplot(1, len(n_eig_list), i+1, projection='3d'))
    axes[i].view_init(azim=-87, elev=10)

for i in range(len(n_eig_list)):
    plt.subplots_adjust(wspace=0, hspace=0)
    p = axes[i].scatter(*X0.T, c=error_per_n_eig[i]['LEGO'], cmap='hot', vmin=0, vmax=1, s=0.25)
    axes[i].set_title(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
    axes[i].axis('off')
    axes[i].axis('equal')
    
#fig.colorbar(p, ax=axes, orientation='vertical', shrink=0.5)
plt.savefig(VIS.save_dir + '/hyperparam_ablation_error_plotted_on_X.png', dpi=600)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Hyperparameter ablation: keeping $m = m_0$

# %%
n_eig_for_grad_list = np.arange(10, 131, 10).astype('int32')
n_eig_list = n_eig_for_grad_list
X_max_noise_level = X.copy()

# %%
error_per_n_eig = {}
for i in range(len(n_eig_list)):
    n_eig_i = int(n_eig_list[i])
    n_eig_for_grad_i = int(n_eig_for_grad_list[i])
    
    lego_estimate_i = lego.lego(
        X_max_noise_level,
        opts={'emb_dim': emb_dim, 'k_nn': k_nn, 'n_eig_for_grad': n_eig_for_grad_i}, 
        gl_opts={'n_eig': n_eig_i}
    )
    

    error_per_n_eig[i] = {
        'LEGO': util.tang_basis_estimate_error(lego_estimate_i['tang_basis'], gt_estimate['tang_basis']),
    }
# Out:
# [LEGO] Diameter normalization & Nearest neighbors: 0.0260 s
# [LEGO] Graph Laplacian spectrum: 0.0888 s
# [LEGO] Gradient first-order approx: 0.0820 s
# [LEGO] Gradient regularization: 0.0080 s
# [LEGO] Tangent basis estimation: 0.8878 s
# [LEGO] Total execution time: 1.0928 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0243 s
# [LEGO] Graph Laplacian spectrum: 0.3777 s
# [LEGO] Gradient first-order approx: 0.0818 s
# [LEGO] Gradient regularization: 0.0283 s
# [LEGO] Tangent basis estimation: 0.8974 s
# [LEGO] Total execution time: 1.4098 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0251 s
# [LEGO] Graph Laplacian spectrum: 0.2448 s
# [LEGO] Gradient first-order approx: 0.0831 s
# [LEGO] Gradient regularization: 0.0172 s
# [LEGO] Tangent basis estimation: 0.9047 s
# [LEGO] Total execution time: 1.2753 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0257 s
# [LEGO] Graph Laplacian spectrum: 0.6009 s
# [LEGO] Gradient first-order approx: 0.0855 s
# [LEGO] Gradient regularization: 0.0060 s
# [LEGO] Tangent basis estimation: 0.8979 s
# [LEGO] Total execution time: 1.6169 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0266 s
# [LEGO] Graph Laplacian spectrum: 0.3356 s
# [LEGO] Gradient first-order approx: 0.0870 s
# [LEGO] Gradient regularization: 0.0078 s
# [LEGO] Tangent basis estimation: 0.8903 s
# [LEGO] Total execution time: 1.3476 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0245 s
# [LEGO] Graph Laplacian spectrum: 0.1685 s
# [LEGO] Gradient first-order approx: 0.0885 s
# [LEGO] Gradient regularization: 0.0108 s
# [LEGO] Tangent basis estimation: 0.9148 s
# [LEGO] Total execution time: 1.2073 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0268 s
# [LEGO] Graph Laplacian spectrum: 0.2370 s
# [LEGO] Gradient first-order approx: 0.0935 s
# [LEGO] Gradient regularization: 0.0611 s
# [LEGO] Tangent basis estimation: 0.9100 s
# [LEGO] Total execution time: 1.3285 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0248 s
# [LEGO] Graph Laplacian spectrum: 0.4042 s
# [LEGO] Gradient first-order approx: 0.0960 s
# [LEGO] Gradient regularization: 0.0872 s
# [LEGO] Tangent basis estimation: 0.9035 s
# [LEGO] Total execution time: 1.5161 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0267 s
# [LEGO] Graph Laplacian spectrum: 0.2866 s
# [LEGO] Gradient first-order approx: 0.0952 s
# [LEGO] Gradient regularization: 0.1523 s
# [LEGO] Tangent basis estimation: 0.8939 s
# [LEGO] Total execution time: 1.4551 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0246 s
# [LEGO] Graph Laplacian spectrum: 0.3227 s
# [LEGO] Gradient first-order approx: 0.0977 s
# [LEGO] Gradient regularization: 0.1883 s
# [LEGO] Tangent basis estimation: 0.9137 s
# [LEGO] Total execution time: 1.5474 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0267 s
# [LEGO] Graph Laplacian spectrum: 0.3408 s
# [LEGO] Gradient first-order approx: 0.1003 s
# [LEGO] Gradient regularization: 0.2571 s
# [LEGO] Tangent basis estimation: 0.9247 s
# [LEGO] Total execution time: 1.6499 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0246 s
# [LEGO] Graph Laplacian spectrum: 0.5916 s
# [LEGO] Gradient first-order approx: 0.1038 s
# [LEGO] Gradient regularization: 0.2950 s
# [LEGO] Tangent basis estimation: 0.9224 s
# [LEGO] Total execution time: 1.9377 s
#
# [LEGO] Diameter normalization & Nearest neighbors: 0.0270 s
# [LEGO] Graph Laplacian spectrum: 0.3435 s
# [LEGO] Gradient first-order approx: 0.1045 s
# [LEGO] Gradient regularization: 0.2921 s
# [LEGO] Tangent basis estimation: 0.9057 s
# [LEGO] Total execution time: 1.6730 s

# %%
color = {'LEGO': 'blue'}
xticks = VIS.global_distortion_viloinplot_overlay(
    error_per_n_eig, log_scale=False,
    legend=False, filled=True, widths=0.75,
    color = color, remove_annotation=False, offset2=0, offset1=1,
    title='', label='', figsize=(6,3), save_fn='hyperparam_ablation'
)
xticks_labels = []
for i in range(len(n_eig_list)):
    xticks_labels.append(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
plt.xticks(np.arange(len(n_eig_for_grad_list)), xticks_labels, fontsize=13)
plt.ylabel('Tangent space\n discrepancy')
plt.xlabel('Hyperparameters')
plt.tight_layout()
plt.savefig(VIS.save_dir + 'hyperparam_same_m_m0_ablation_annotated.png', dpi=600)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure(figsize=(len(n_eig_list)*0.9, 2))
axes = []
for i in range(len(n_eig_list)):
    axes.append(fig.add_subplot(1, len(n_eig_list), i+1, projection='3d'))
    axes[i].view_init(azim=-87, elev=10)

for i in range(len(n_eig_list)):
    plt.subplots_adjust(wspace=0, hspace=0)
    p = axes[i].scatter(*X0.T, c=error_per_n_eig[i]['LEGO'], cmap='hot', vmin=0, vmax=1, s=0.25)
    axes[i].set_title(str(n_eig_for_grad_list[i])+'\n'+str(n_eig_list[i]))
    axes[i].axis('off')
    axes[i].axis('equal')
    
#fig.colorbar(p, ax=axes, orientation='vertical', shrink=0.5)
plt.savefig(VIS.save_dir + '/hyperparam_ablation_error_same_m_m0_plotted_on_X.png', dpi=600)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
